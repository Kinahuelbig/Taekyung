# %% [markdown]
# <a href="https://colab.research.google.com/github/Kinahuelbig/Taekyung/blob/master/Module6_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
sns.set()

import warnings
warnings.filterwarnings("ignore")

# %%
houseprices_df = pd.read_csv('houseprices.csv')
houseprices_df.head()
# Out:
#    id  mssubclass mszoning  ...  saletype  salecondition saleprice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
houseprices_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1460 non-null   int64
#  1   mssubclass     1460 non-null   int64
#  2   mszoning       1460 non-null   object
#  3   lotfrontage    1201 non-null   float64
#  4   lotarea        1460 non-null   int64
#  5   street         1460 non-null   object
#  6   alley          91 non-null     object
#  7   lotshape       1460 non-null   object
#  8   landcontour    1460 non-null   object
#  9   utilities      1460 non-null   object
#  10  lotconfig      1460 non-null   object
#  11  landslope      1460 non-null   object
#  12  neighborhood   1460 non-null   object
#  13  condition1     1460 non-null   object
#  14  condition2     1460 non-null   object
#  15  bldgtype       1460 non-null   object
#  16  housestyle     1460 non-null   object
# ...

# %%
#Q1
ax= sns.distplot(houseprices_df['saleprice'])

# %%
#Q2
ax= sns.distplot(houseprices_df['lotarea'])

# %%
#Q3
sns.boxplot(y="overallcond", x="sale price" , data= houseprices_df);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4934549ce4a7> in <module>()
# ----> 1 sns.boxplot(y="overallcond", x="sale price" , data= houseprices_df);
#
# NameError: name 'sns' is not defined

# %%
#Q4
ax=sns.boxplot(y="overallcond",hue= "having central air conditioning", x="sale price" , data= houseprices_df);
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5b433229a8e0> in <module>()
# ----> 1 ax=sns.boxplot(y="overallcond",hue= "having central air conditioning", x="sale price" , data= houseprices_df);
#       2 ax.set_xticklabels(ax.get_xticklabels(), rotation=90);
#
# NameError: name 'sns' is not defined

# %%
#Q5.
sns.scatterplot(x="lotarea", y= "saleprice", data=houseprices_df);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-71ca09281aea> in <module>()
# ----> 1 sns.scatterplot(x="lotarea", y= "saleprice", data=houseprices_df);
#
# NameError: name 'sns' is not defined
